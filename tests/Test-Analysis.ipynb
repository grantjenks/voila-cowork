# %% [markdown]
# # Test Code for Jupyter Comments
#
# See README.org for notes.

# %%
import cowork
import numpy as np
import pandas as pd

# %%
np.random.seed(0)

# %%
await cowork.setup('gjenks', 'Test-Analysis')
# Out:
#             <style>
#               .jp-Notebook {
#                 background: lightgray;
#               }
#
#               #rendered_cells {
#                 display: inherit !important;
#                 max-width: 960px;
#                 margin: 0 auto;
#                 padding: 96px;
#                 box-shadow: 0 0 4px 4px gray;
#                 background: white;
#               }
#             </style>
#             <script src="https://unpkg.com/htmx.org@1.3.0"></script>

# %%
changes = np.random.choice([-1, 1], 1000)
values = np.cumsum(changes)
df = pd.DataFrame({'values': values}, index=range(1000))

# %%
ax = df.plot(
    figsize=(12, 8),
    title='Random Walk',
)
None

# %%
await cowork.comments('Random-Walk')
# Out:
# <!doctype html>
# <html>
#   <head>
#     <script src="https://unpkg.com/htmx.org@1.3.0"></script>
#   </head>
#   <body>
#     <div id="comments-topic">
#       <h3>Comments</h3>
#       <form
#           hx-post="http://localhost:58952/gjenks/Test-Analysis/Random-Walk/comments/"
#           hx-select="#comments-topic"
#           hx-target="#comments-topic"
#           method="POST"
#           action="http://localhost:58952/gjenks/Test-Analysis/Random-Walk/comments/"
#       >
#         <tr><th><label for="id_username">Username:</label></th><td><input type="text" name="username" autofocus autocapitalize="none" autocomplete="username" maxlength="150" required id="id_username"></td></tr>
# <tr><th><label for="id_password">Password:</label></th><td><input type="password" name="password" autocomplete="current-password" required id="id_password"></td></tr>
# ...
